# %%
import pandas as pd

# %%
new_test = pd.read_csv('chase_ios_app_reviews.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_test.describe()
# Out:
#               rating
# count  131983.000000
# mean        4.349181
# std         1.226626
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
new_test.head(10)
# Out:
#           date version  rating  \
# 0  aug 05 2017   2.623       5
# 1  aug 15 2017   2.623       1
# 2  aug 16 2017   2.623       1
# 3  aug 28 2017   2.623       3
# 4  aug 11 2017   2.623       5
# 5  sep 29 2017   2.634       5
# 6  aug 01 2017   2.623       5
# 7  aug 02 2017   2.623       5
# 8  oct 05 2017   2.634       2
# 9  sep 02 2017   2.623       4
#
#                                                 body
# 0   i use this app every day its pretty simply la...
# 1   your password expires but it doesnt tell you ...
# 2   when you check your balance the addition is a...
# 3   this app is great when it actually works righ...
# 4   ive been a member for + years when chase made...
# 5   its been more than six months since i wrote m...
# 6   i love this app i use this app daily to monit...
# 7   i moved  years ago and the nearest chase bank...
# 8   i have been using this app for years and neve...
# 9   the current version of the app allows you to ...

# %%
listest = pd.unique(new_test['version'])

# %%
listest = [1,2,3]

# %%
listest
# Out:
# array(['2.623', '2.634', '2.635', '2.651', '2.652', '2.54', '2.471', '0',
#        '2.61', '2.461', '2.48', '2.28', '2.25', '2.55', '2.56', '2.23',
#        '2.5', '2.62', ' 2.14.5799', '2.44', '2.45', '2.49', '2.41',
#        '2.401', ' 2.10.3018', '2.57', '2.42', ' 2.8.1202', '2.34', '2.24',
#        '2.8', '2.4', '2.331', ' 2.12.3856', '2.59', ' 2.11.3472', '2.31',
#        '2.32', ' 2.10.2911', ' 2.162.8101', '2.18', '2.17', '2.21', '2.36',
#        '2.621', ' 2.13. 4542', '2.16', '2.39', '2.38', '2.43', '2.27',
#        ' 2.15.6106', '2.35', '2.2', '2.46', '2.3', '2.622', '2.26', '2.19',
#        '2.47', '2.53', '2.29', '2.7', '2.51', 2.61, 2.59, 2.62,
#        2.6210000000000004, 2.622, 2.623, 2.634, 2.635, 2.6510000000000002,
#        2.6519999999999997], dtype=object)

# %%
for x in listest:
    print("test%f" %x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6db4a3d4fc3d> in <module>()
#       1 for x in listest:
# ----> 2     print("test%f" %x)
#
# TypeError: must be real number, not str

# %%
sample_data = new_test[new_test.version == listest[1] ]
sample_data
# Out:
#                date version  rating  \
# 5       sep 29 2017   2.634       5
# 8       oct 05 2017   2.634       2
# 11      oct 02 2017   2.634       5
# 14      oct 01 2017   2.634       5
# 15      sep 30 2017   2.634       5
# 19      oct 06 2017   2.634       2
# 21      sep 29 2017   2.634       3
# 23      oct 09 2017   2.634       1
# 26      sep 27 2017   2.634       5
# 27      sep 30 2017   2.634       5
# 31      oct 09 2017   2.634       4
# 39      sep 26 2017   2.634       3
# 44      oct 02 2017   2.634       5
# 45      sep 29 2017   2.634       5
# 46      oct 02 2017   2.634       3
# 49      oct 03 2017   2.634       5
# 53      oct 08 2017   2.634       5
# 54      oct 19 2017   2.634       4
# 56      oct 23 2017   2.634       5
# 57      oct 05 2017   2.634       1
# 59      oct 17 2017   2.634       3
# 65      sep 29 2017   2.634       5
# 67      sep 28 2017   2.634       3
# 70      oct 02 2017   2.634       2
# 71      oct 04 2017   2.634       5
# 72      oct 13 2017   2.634       5
# 73      oct 14 2017   2.634       4
# 76      oct 12 2017   2.634       4
# 77      oct 13 2017   2.634       1
# 78      oct 30 2017   2.634       2
# ...             ...     ...     ...
# 126763  oct 05 2017   2.634       5
# 126764  oct 05 2017   2.634       5
# 126765  oct 06 2017   2.634       5
# 126766  oct 06 2017   2.634       5
# 126767  oct 06 2017   2.634       5
# 126768  oct 08 2017   2.634       5
# 126769  oct 08 2017   2.634       5
# 126770  oct 08 2017   2.634       5
# 126771  oct 09 2017   2.634       4
# 126772  oct 09 2017   2.634       5
# 126773  oct 10 2017   2.634       5
# 126774  oct 10 2017   2.634       5
# 126775  oct 17 2017   2.634       5
# 126776  oct 19 2017   2.634       5
# 126777  oct 19 2017   2.634       1
# 126778  oct 19 2017   2.634       5
# 126779  oct 20 2017   2.634       5
# 126780  oct 20 2017   2.634       5
# 126781  oct 21 2017   2.634       5
# 126782  oct 21 2017   2.634       5
# 126783  oct 22 2017   2.634       5
# 126784  oct 24 2017   2.634       5
# 126785  oct 25 2017   2.634       1
# 126786  oct 26 2017   2.634       5
# 126787  oct 26 2017   2.634       5
# 126788  oct 27 2017   2.634       5
# 126789  oct 28 2017   2.634       5
# 126790  nov 04 2017   2.634       5
# 126793  sep 29 2017   2.634       5
# 126794  sep 30 2017   2.634       5
#
#                                                      body
# 5        its been more than six months since i wrote m...
# 8        i have been using this app for years and neve...
# 11       the banking app for chase is very easy to nav...
# 14       bank from anywhere  put your financial life i...
# 15       i have the update that came out a few months ...
# 19       i really do like that i can deposit checks us...
# 21       i switched banks to use this app super conven...
# 23       chases user interface for depositing checks h...
# 26       im usually really bad at keeping track of my ...
# 27       i really like my mobil apt i use it every day...
# 31       the app doesnt ask you to use the iphone came...
# 39       it was too good to last the app design has ta...
# 44       great day when i switched to chase some  year...
# 45       this app is great i can only compare it to bo...
# 46       i need to start by saying the chase sapphire ...
# 49       im really happy with this app it works great ...
# 53       i actually look forward to logging in and che...
# 54       this is an easy app once you have learned you...
# 56       this app allows you to set alerts that can se...
# 57       easy to use and very helpful better then the ...
# 59       this a robust app  very functional and put to...
# 65       ive been using this app for the past + years ...
# 67       the app is ok when you view your account its ...
# 70       this app is okay but needs more work i use tw...
# 71       pretty much what the title says i find this a...
# 72       im a business owner and im pretty much on my ...
# 73       ive enjoyed using the chase app  and i think ...
# 76       originally i had problems logging in the fing...
# 77       at first this app seemed wonderful i could ma...
# 78       the app is okay the calculation portion of it...
# ...                                                   ...
# 126763                                   i like it a lot
# 126764   muy bueno ases todo aqui puedes mirar los que...
# 126765                                          muy bien
# 126766                                        convenient
# 126767                                           love it
# 126768   me gusta esta aplicaci??n  as?? se puede sabe...
# 126769   esta s??per est?? aplicaci??n estoy muy satis...
# 126770                                             buena
# 126771                                    i love banking
# 126772   muy f??cil de usar ??til e intuitiva organiza...
# 126773                              quick and efficient
# 126774               muy buena aplicacion me ayuda mucho
# 126775                              keeps getting better
# 126776                              good app development
# 126777                ??€?????????????€€ ?????€?????€???
# 126778   es una aplikacion nastante interesante y muy ...
# 126779                                         very good
# 126780   esta s??per buena esta aplicaci??n se las rec...
# 126781             best banking app keeps getting better
# 126782                                        killer app
# 126783   me encanta la aplicaci??n de chase es una apl...
# 126784                     muy buena aplicaci??n gracias
# 126785                  no me deja ver mis transacciones
# 126786                                 easy  fast i like
# 126787   est?? calidad esta aplicaci??n y r??pida pa h...
# 126788   very good     me gusta mucho pues es importan...
# 126789
# 126790                                         great app
# 126793                   keeps getting better and better
# 126794
#
# [4533 rows x 4 columns]
